# %%
import tensorflow as tf
from tensorflow import keras
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 272s 1us/step

# %%
import pathlib

# %%
data_dir=pathlib.Path(data_dir)

# %%
rose=list(data_dir.glob('roses/*jpg'))

# %%
import PIL
from keras.preprocessing import image

# %%
PIL.Image.open(str(rose[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x231 at 0x1F39ABA36D0>

# %%
tulips=list(data_dir.glob('tulips/*'))

# %%
PIL.Image.open(tulips[2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335 at 0x1F39ABA3370>

# %%
daisy=list(data_dir.glob('daisy/*'))

# %%
PIL.Image.open(daisy[5])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x400 at 0x1F39ABA3820>

# %%
sunflower=list(data_dir.glob('sunflowers/*'))

# %%
PIL.Image.open(sunflower[1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x1F3B0D44460>

# %%
dandelion=list(data_dir.glob('dandelion/*'))
PIL.Image.open(dandelion[6])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213 at 0x1F3B1F60370>
